# %% [markdown]
# # Gradio Demo: waveform

# %%
# !pip install -q gradio
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.1 requires pyqt5<5.16, which is not installed.
# spyder 5.4.1 requires pyqtwebengine<5.16, which is not installed.
# argilla 1.6.0 requires pandas<2.0.0,>=1.0.0, but you have pandas 2.0.1 which is incompatible.

# %%
import gradio as gr
import random


COLORS = [
    ["#ff0000", "#00ff00"],
    ["#00ff00", "#0000ff"],
    ["#0000ff", "#ff0000"],
]    

def audio_waveform(audio, image):
    return (
        audio,
        gr.make_waveform(audio),
        gr.make_waveform(audio, bg_image=image, bars_color=random.choice(COLORS)),
    )


gr.Interface(
    audio_waveform,
    inputs=[gr.Audio(), gr.Image(type="filepath")],
    outputs=[
        gr.Audio(),
        gr.Video(),
        gr.Video(),
    ],
).launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, png_pipe, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmp3enreujx.png':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpy9nocoo4.wav':
#   Duration: 00:00:10.00, bitrate: 1536 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fc292f09980] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fc292f09980] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x7fc292f09980] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmptjmk5x7x.mp4':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1000x200, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 aac
# frame=  250 fps=0.0 q=-1.0 Lsize=     197kB time=00:00:09.98 bitrate= 161.8kbits/s speed=13.2x
# video:33kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.495615%
# [libx264 @ 0x7fc292f09980] frame I:1     Avg QP:21.16  size:  6538
# [libx264 @ 0x7fc292f09980] frame P:123   Avg QP:21.61  size:   160
# [libx264 @ 0x7fc292f09980] frame B:126   Avg QP:18.96  size:    51
# [libx264 @ 0x7fc292f09980] consecutive B-frames: 23.2% 16.0% 38.4% 22.4%
# [libx264 @ 0x7fc292f09980] mb I  I16..4: 60.3% 19.0% 20.6%
# [libx264 @ 0x7fc292f09980] mb P  I16..4:  1.3%  0.7%  0.1%  P16..4:  4.2%  0.4%  0.1%  0.0%  0.0%    skip:93.3%
# [libx264 @ 0x7fc292f09980] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  2.9%  0.2%  0.0%  direct: 0.0%  skip:96.6%  L0:52.2% L1:47.2% BI: 0.6%
# [libx264 @ 0x7fc292f09980] 8x8 transform intra:28.8% inter:51.5%
# [libx264 @ 0x7fc292f09980] coded y,uvDC,uvAC intra: 4.1% 10.1% 8.2% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x7fc292f09980] i16 v,h,dc,p: 96%  1%  3%  0%
# [libx264 @ 0x7fc292f09980] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  2% 86%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x7fc292f09980] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 66% 18% 12%  0%  1%  1%  1%  1%  0%
# [libx264 @ 0x7fc292f09980] i8c dc,h,v,p: 42%  4% 54%  0%
# [libx264 @ 0x7fc292f09980] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fc292f09980] ref P L0: 90.8%  0.4%  6.1%  2.7%
# [libx264 @ 0x7fc292f09980] ref B L0: 75.2% 16.4%  8.3%
# [libx264 @ 0x7fc292f09980] ref B L1: 98.6%  1.4%
# [libx264 @ 0x7fc292f09980] kb/s:26.08
# [aac @ 0x7fc292f0adc0] Qavg: 210.217
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, png_pipe, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpxz65tzov.png':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpsyq_wpnt.wav':
#   Duration: 00:00:10.00, bitrate: 1536 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7f7af6a087c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7f7af6a087c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x7f7af6a087c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmp8f9vg961.mp4':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1000x200, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 aac
# frame=  250 fps=0.0 q=-1.0 Lsize=     198kB time=00:00:09.98 bitrate= 162.3kbits/s speed=12.7x
# video:33kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.464134%
# [libx264 @ 0x7f7af6a087c0] frame I:1     Avg QP:23.19  size:  5855
# [libx264 @ 0x7f7af6a087c0] frame P:136   Avg QP:23.85  size:   160
# [libx264 @ 0x7f7af6a087c0] frame B:113   Avg QP:17.61  size:    50
# [libx264 @ 0x7f7af6a087c0] consecutive B-frames: 26.4% 28.0% 36.0%  9.6%
# [libx264 @ 0x7f7af6a087c0] mb I  I16..4: 60.7% 18.3% 21.0%
# [libx264 @ 0x7f7af6a087c0] mb P  I16..4:  1.5%  0.7%  0.1%  P16..4:  4.0%  0.2%  0.1%  0.0%  0.0%    skip:93.5%
# [libx264 @ 0x7f7af6a087c0] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  2.8%  0.2%  0.0%  direct: 0.0%  skip:96.6%  L0:50.0% L1:49.7% BI: 0.3%
# [libx264 @ 0x7f7af6a087c0] 8x8 transform intra:29.2% inter:32.1%
# [libx264 @ 0x7f7af6a087c0] coded y,uvDC,uvAC intra: 3.4% 9.7% 7.9% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x7f7af6a087c0] i16 v,h,dc,p: 95%  2%  3%  0%
# [libx264 @ 0x7f7af6a087c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9%  2% 89%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x7f7af6a087c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 68% 17% 10%  0%  1%  1%  1%  1%  1%
# [libx264 @ 0x7f7af6a087c0] i8c dc,h,v,p: 39%  8% 54%  0%
# [libx264 @ 0x7f7af6a087c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7f7af6a087c0] ref P L0: 90.7%  0.4%  5.7%  3.2%
# [libx264 @ 0x7f7af6a087c0] ref B L0: 83.3% 10.5%  6.2%
# [libx264 @ 0x7f7af6a087c0] ref B L1: 99.1%  0.9%
# [libx264 @ 0x7f7af6a087c0] kb/s:26.60
# [aac @ 0x7f7af6a09c00] Qavg: 210.217
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, png_pipe, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmp3yp0v52a.png':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpvqm9wjc3.wav':
#   Duration: 00:00:10.00, bitrate: 1536 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7f9eae10ab40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7f9eae10ab40] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x7f9eae10ab40] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpzwv_6b9t.mp4':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1000x200, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 aac
# frame=  250 fps=0.0 q=-1.0 Lsize=     197kB time=00:00:09.98 bitrate= 161.8kbits/s speed=11.9x
# video:33kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.495615%
# [libx264 @ 0x7f9eae10ab40] frame I:1     Avg QP:21.16  size:  6538
# [libx264 @ 0x7f9eae10ab40] frame P:123   Avg QP:21.61  size:   160
# [libx264 @ 0x7f9eae10ab40] frame B:126   Avg QP:18.96  size:    51
# [libx264 @ 0x7f9eae10ab40] consecutive B-frames: 23.2% 16.0% 38.4% 22.4%
# [libx264 @ 0x7f9eae10ab40] mb I  I16..4: 60.3% 19.0% 20.6%
# [libx264 @ 0x7f9eae10ab40] mb P  I16..4:  1.3%  0.7%  0.1%  P16..4:  4.2%  0.4%  0.1%  0.0%  0.0%    skip:93.3%
# [libx264 @ 0x7f9eae10ab40] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  2.9%  0.2%  0.0%  direct: 0.0%  skip:96.6%  L0:52.2% L1:47.2% BI: 0.6%
# [libx264 @ 0x7f9eae10ab40] 8x8 transform intra:28.8% inter:51.5%
# [libx264 @ 0x7f9eae10ab40] coded y,uvDC,uvAC intra: 4.1% 10.1% 8.2% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x7f9eae10ab40] i16 v,h,dc,p: 96%  1%  3%  0%
# [libx264 @ 0x7f9eae10ab40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  2% 86%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x7f9eae10ab40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 66% 18% 12%  0%  1%  1%  1%  1%  0%
# [libx264 @ 0x7f9eae10ab40] i8c dc,h,v,p: 42%  4% 54%  0%
# [libx264 @ 0x7f9eae10ab40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7f9eae10ab40] ref P L0: 90.8%  0.4%  6.1%  2.7%
# [libx264 @ 0x7f9eae10ab40] ref B L0: 75.2% 16.4%  8.3%
# [libx264 @ 0x7f9eae10ab40] ref B L1: 98.6%  1.4%
# [libx264 @ 0x7f9eae10ab40] kb/s:26.08
# [aac @ 0x7f9eae10c040] Qavg: 210.217
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, png_pipe, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpnj0klv1e.png':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpjkt13x9b.wav':
#   Duration: 00:00:10.00, bitrate: 1536 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fd381214100] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fd381214100] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x7fd381214100] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmp1lzsp3yb.mp4':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1000x200, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 aac
# frame=  250 fps=0.0 q=-1.0 Lsize=     198kB time=00:00:09.98 bitrate= 162.3kbits/s speed=11.9x
# video:33kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.469527%
# [libx264 @ 0x7fd381214100] frame I:1     Avg QP:23.08  size:  6123
# [libx264 @ 0x7fd381214100] frame P:135   Avg QP:22.14  size:   160
# [libx264 @ 0x7fd381214100] frame B:114   Avg QP:17.61  size:    48
# [libx264 @ 0x7fd381214100] consecutive B-frames: 26.0% 27.2% 37.2%  9.6%
# [libx264 @ 0x7fd381214100] mb I  I16..4: 46.3% 32.7% 21.0%
# [libx264 @ 0x7fd381214100] mb P  I16..4:  1.3%  0.6%  0.1%  P16..4:  4.0%  0.3%  0.1%  0.0%  0.0%    skip:93.7%
# [libx264 @ 0x7fd381214100] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  2.8%  0.2%  0.0%  direct: 0.0%  skip:96.8%  L0:51.9% L1:47.7% BI: 0.3%
# [libx264 @ 0x7fd381214100] 8x8 transform intra:32.1% inter:39.6%
# [libx264 @ 0x7fd381214100] coded y,uvDC,uvAC intra: 3.8% 10.5% 8.9% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x7fd381214100] i16 v,h,dc,p: 96%  1%  3%  0%
# [libx264 @ 0x7fd381214100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19%  3% 76%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x7fd381214100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 59% 16% 20%  0%  1%  1%  1%  1%  1%
# [libx264 @ 0x7fd381214100] i8c dc,h,v,p: 38%  5% 57%  0%
# [libx264 @ 0x7fd381214100] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fd381214100] ref P L0: 92.3%  0.3%  5.4%  2.0%
# [libx264 @ 0x7fd381214100] ref B L0: 79.7% 12.0%  8.3%
# [libx264 @ 0x7fd381214100] ref B L1: 98.8%  1.2%
# [libx264 @ 0x7fd381214100] kb/s:26.56
# [aac @ 0x7fd381215640] Qavg: 210.217
