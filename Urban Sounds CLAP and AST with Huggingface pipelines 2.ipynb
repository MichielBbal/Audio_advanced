# %% [markdown]
# # Huggingface audio pipelines
# source: https://huggingface.co/learn/audio-course/chapter2/audio_classification_pipeline?fw=pt
#
#
# ### Contents
# 0. Install packages
# 1. First script
# 2. CLAP on the Urban Sounds Amsterdam dataset
# 3. AST on the Urban Sounds Amsterdam dataset

# %% [markdown]
# ## Introduction
#
# ### Using datasets
# To classify sounds, I've uploaded a sub-sample of the Amsterdam Sounds Database at Huggingface.
#
# In this notebook we will use HUggingface's ```dataset``` library to load this dataset.
#
# links:
# - https://pypi.org/project/datasets/
# - https://huggingface.co/docs/datasets/audio_process
# - https://huggingface.co/docs/datasets/v2.14.5/en/package_reference/main_classes#datasets.Audio

# %% [markdown]
# # 0. Install packages

# %%
#!pip install datasets

# %%
pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install datasets\[audio\]
# Out:
# Requirement already satisfied: datasets[audio] in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (2.14.5)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (3.8.4)
# Requirement already satisfied: numpy>=1.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (1.23.5)
# Requirement already satisfied: xxhash in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (3.2.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (23.1)
# Requirement already satisfied: multiprocess in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (0.70.14)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (6.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (2.31.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (11.0.0)
# Requirement already satisfied: pandas in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (2.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (0.18.0)
# Requirement already satisfied: librosa in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (0.10.0.post2)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets[audio]) (0.12.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets[audio]) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets[audio]) (4.4.0)
# Requirement already satisfied: filelock in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets[audio]) (3.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets[audio]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets[audio]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets[audio]) (2022.12.7)
# Requirement already satisfied: cffi>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from soundfile>=0.12.1->datasets[audio]) (1.15.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (1.4.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (1.3.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (1.10.0)
# Requirement already satisfied: numba>=0.51.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (0.57.1)
# Requirement already satisfied: soxr>=0.3.2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (0.3)
# Requirement already satisfied: audioread>=2.1.9 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (3.0.0)
# Requirement already satisfied: msgpack>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (1.0.3)
# Requirement already satisfied: joblib>=0.14 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from librosa->datasets[audio]) (4.4.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas->datasets[audio]) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas->datasets[audio]) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas->datasets[audio]) (2023.3)
# Requirement already satisfied: pycparser in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa->datasets[audio]) (0.40.1)
# Requirement already satisfied: appdirs in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pooch<1.7,>=1.0->librosa->datasets[audio]) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets[audio]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa->datasets[audio]) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#check numpy version is 1.24
import numpy as np
np.__version__
# Out:
# '1.24.0'

# %% [markdown]
# ## 1. Audio classification with a pipeline
#
# source: https://huggingface.co/learn/audio-course/chapter2/audio_classification_pipeline?fw=pt

# %%
from datasets import load_dataset
from datasets import Audio

minds = load_dataset("PolyAI/minds14", name="en-AU", split="train")
minds = minds.cast_column("audio", Audio(sampling_rate=16_000))

# %%
from transformers import pipeline

classifier = pipeline(
    "audio-classification",
    model="anton-l/xtreme_s_xlsr_300m_minds14",
)

# %%
example = minds[0]
classifier(example["audio"]["array"])
# Out:
# [{'score': 0.9625310301780701, 'label': 'pay_bill'},
#  {'score': 0.028672754764556885, 'label': 'freeze'},
#  {'score': 0.0033497940748929977, 'label': 'card_issues'},
#  {'score': 0.0020058027002960443, 'label': 'abroad'},
#  {'score': 0.000848432769998908, 'label': 'high_value_payment'}]

# %%
example
# Out:
# {'path': '/Users/michielbontenbal/.cache/huggingface/datasets/downloads/extracted/91523c3a7f67fb2017e19a89742e7c63e1f07d178e1bb911001f7434d12237ee/en-AU~PAY_BILL/response_4.wav',
#  'audio': {'path': '/Users/michielbontenbal/.cache/huggingface/datasets/downloads/extracted/91523c3a7f67fb2017e19a89742e7c63e1f07d178e1bb911001f7434d12237ee/en-AU~PAY_BILL/response_4.wav',
#   'array': array([2.36120541e-05, 1.92325111e-04, 2.19285139e-04, ...,
#          9.40908212e-04, 1.16613181e-03, 7.20883720e-04]),
#   'sampling_rate': 16000},
#  'transcription': 'I would like to pay my electricity bill using my card can you please assist',
#  'english_transcription': 'I would like to pay my electricity bill using my card can you please assist',
#  'intent_class': 13,
#  'lang_id': 2}

# %%
#look up the label
id2label = minds.features["intent_class"].int2str
id2label(example["intent_class"])
# Out:
# 'pay_bill'

# %% [markdown]
# ## 2. CLAP on the Urban Sounds Amsterdam dataset
#
# Source: https://huggingface.co/laion/larger_clap_general
#
# Paper: https://arxiv.org/abs/2211.06687
#
# CLAP (Contrastive Language-Audio Pretraining) is a neural network trained on a variety of (audio, text) pairs. It can be instructed in to predict the most relevant text snippet, given an audio, without directly optimizing for the task.

# %%
from datasets import load_dataset

dataset = load_dataset("MichielBontenbal/UrbanSounds")
# Out:
# Resolving data files:   0%|          | 0/239 [00:00<?, ?it/s]

# %%
#inspect the dataset
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio'],
#         num_rows: 238
#     })
# })

# %%
from transformers import ClapModel, ClapProcessor
from transformers import pipeline
import IPython

example = dataset['train']['audio'][1]
audio = dataset["train"]["audio"][-1]["array"]

audio_classifier = pipeline(task="zero-shot-audio-classification", model="laion/larger_clap_music_and_speech")
output = audio_classifier(audio, candidate_labels=["Motorcycle", "Moped", 'Claxon','Alarm', 'Silence','Loud people','Talking','Gunshot', 'Slamming door','Music'])
print(output[0],output[1], output[2])
IPython.display.Audio(example["array"], rate=example['sampling_rate'])
# Out:
# {'score': 0.9225516319274902, 'label': 'Gunshot'} {'score': 0.061576180160045624, 'label': 'Loud people'} {'score': 0.013743710704147816, 'label': 'Slamming door'}
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# You may notice that the audio column contains several features. Here’s what they are:
#
# - path: the path to the audio file
# - array: The decoded audio data, represented as a 1-dimensional NumPy array.
# - sampling_rate. The sampling rate of the audio file.

# %%
#print the example
example
# Out:
# {'path': '/Users/michielbontenbal/.cache/huggingface/datasets/downloads/261be9491a75f8b854776ced14c604eba19e34b4a4cb4244de6afe4e615d0413',
#  'array': array([-0.02656555, -0.03103638, -0.03013611, ..., -0.00975037,
#         -0.00650024,  0.        ]),
#  'sampling_rate': 48000}

# %%
example['sampling_rate']
# Out:
# 44100

# %%
print(type(audio))
print(audio.shape)
print(audio.dtype)
print(audio.nbytes)
# Out:
# <class 'numpy.ndarray'>
# (441000,)
# float64
# 3528000

# %%
#check length of dataset

print(len(dataset['train']['audio']))
print(type(dataset['train']['audio']))
# Out:
# 238
# <class 'list'>

# %%
#the display script
from IPython.display import Audio

Audio(example["array"], rate=example['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#a short script to get a number from the list
import random
my_list = [i for i in range(0, len(dataset['train']['audio']))]

# Getting a random number from the list
random_number = random.choice(my_list)
print(random_number)
# Out:
# 184

# %%
# %%time
#Script to load a random number out of the dataset
from transformers import ClapModel, ClapProcessor
from transformers import pipeline
from datasets import load_dataset
import IPython

#dataset = load_dataset("MichielBontenbal/UrbanSounds") #uncomment if you want to load it

#creat an example file with the accomp
example=dataset['train']['audio'][random_number]
audio = dataset["train"]["audio"][random_number]["array"]

audio_classifier = pipeline(task="zero-shot-audio-classification", model="laion/larger_clap_general")
output = audio_classifier(audio, candidate_labels=["Motorcycle", "Moped", 'Claxon','Alarm', 'Silence','Loud people','Talking','Gunshot', 'Slamming door','Music'])
print(output[0],'\n',output[1])
print(random_number)
IPython.display.Audio(example["array"], rate=example['sampling_rate'])
# Out:
# {'score': 0.9141817092895508, 'label': 'Music'}
#  {'score': 0.02761041186749935, 'label': 'Motorcycle'}
# 184
# CPU times: user 7.93 s, sys: 2 s, total: 9.94 s
# Wall time: 7.63 s
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Audio Spectrum Transfomer with Urban Sounds Amsterdam Dataset
#
# Model: https://huggingface.co/MIT/ast-finetuned-audioset-10-10-0.4593
# Paper: https://arxiv.org/abs/2104.01778

# %%
from transformers import AutoFeatureExtractor, ASTForAudioClassification
from datasets import load_dataset
import torch

dataset = load_dataset("MichielBontenbal/UrbanSounds")

feature_extractor = AutoFeatureExtractor.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593")
model = ASTForAudioClassification.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593")

# audio file is decoded on the fly
inputs = feature_extractor(dataset['train']["audio"][random_number]["array"], sampling_rate=16000, return_tensors="pt")

with torch.no_grad():
    logits = model(**inputs).logits

predicted_class_ids = torch.argmax(logits, dim=-1).item()
predicted_label = model.config.id2label[predicted_class_ids]
print(predicted_label)

# compute loss - target_label is e.g. "down"
target_label = model.config.id2label[0]
inputs["labels"] = torch.tensor([model.config.label2id[target_label]])
loss = model(**inputs).loss
print(round(loss.item(), 2))
# Out:
# Resolving data files:   0%|          | 0/239 [00:00<?, ?it/s]
# Music
# 2.23

# %%
import IPython
example=dataset['train']["audio"][random_number]
IPython.display.Audio(example["array"], rate=example['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
